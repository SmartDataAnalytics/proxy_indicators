# %%
import pandas as pd
import numpy as np

import pathlib
import json
import glob

from sklearn.preprocessing import minmax_scale
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr, spearmanr

import seaborn as sns
import matplotlib.pyplot as plt

from pprint import pprint

# %%
pair_predictions = ['mrpc','qnli','qqp','rte','stsb',]
fact_predictions = [f"fact_{p_p}" for p_p in pair_predictions]
single_predictions = ['cola', 'sst']
all_scores = single_predictions + pair_predictions + fact_predictions
criteria_names = ['Understandable', 'Natural', 'Maintains Context', 'Engaging', 'Uses Knowledge', 'Overall']

# %%
with open("../data/eval_usr_percona_chat.json", "rt") as fin:
    dialogue_data = json.load(fin)
    
dialogue_data_df = list()

for dialogue in dialogue_data:
    for response in dialogue["responses"]:
        row = dict(response)
        
        for criterium in criteria_names:
            row[criterium] = np.average(row[criterium])
        
        row.pop("response", None)
        row.pop("model", None)
        
        dialogue_data_df.append(row)
        
dialogue_data_df = pd.DataFrame(dialogue_data_df)
dialogue_data_df.shape
# Out:
# (300, 18)

# %%
dialogue_data_df.head(1)
# Out:
#    Understandable  Natural  Maintains Context  Engaging  Uses Knowledge  \
# 0             1.0      3.0                3.0  1.333333             0.0
#
#     Overall      cola       sst      mrpc  fact_mrpc       qqp  fact_qqp  \
# 0  3.666667  0.628361  0.123976  0.165805   0.109548  0.000108  0.000088
#
#        stsb  fact_stsb      qnli  fact_qnli       rte  fact_rte
# 0  1.201328   0.579063  0.041934   0.398787  0.097636  0.947536

# %%
for column in (criteria_names + all_scores):
    dialogue_data_df[column] = minmax_scale(dialogue_data_df[column])

# %%
lin_model = LinearRegression(fit_intercept=True).fit(
    X=dialogue_data_df[pair_predictions].to_numpy(),
    y=dialogue_data_df["Overall"].to_numpy()
)
dialogue_data_df["lin-reg_pair"] = lin_model.predict(dialogue_data_df[pair_predictions].to_numpy())

pprint(list(zip(pair_predictions, lin_model.coef_)) + [lin_model.intercept_])
# Out:
# [('mrpc', 0.45147490627866715),
#  ('qnli', -0.1469290258480331),
#  ('qqp', -0.3615345399496674),
#  ('rte', 0.16524145269323834),
#  ('stsb', 0.4143835059107151),
#  0.38886033611650206]

# %%
lin_model = LinearRegression(fit_intercept=True).fit(
    X=dialogue_data_df[fact_predictions].to_numpy(),
    y=dialogue_data_df["Overall"].to_numpy()
)
dialogue_data_df["lin-reg_fact"] = lin_model.predict(dialogue_data_df[fact_predictions].to_numpy())

pprint(list(zip(fact_predictions, lin_model.coef_)) + [lin_model.intercept_])
# Out:
# [('fact_mrpc', -0.09542596137493763),
#  ('fact_qnli', -0.059350418415453896),
#  ('fact_qqp', 0.029504507039982097),
#  ('fact_rte', 0.12499483475104593),
#  ('fact_stsb', 0.5539559369418295),
#  0.43540192831134983]

# %%
lin_model = LinearRegression(fit_intercept=True).fit(
    X=dialogue_data_df[single_predictions].to_numpy(),
    y=dialogue_data_df["Overall"].to_numpy()
)
dialogue_data_df["lin-reg_single"] = lin_model.predict(dialogue_data_df[single_predictions].to_numpy())

pprint(list(zip(single_predictions, lin_model.coef_)) + [lin_model.intercept_])
# Out:
# [('cola', -0.03490555282150484),
#  ('sst', 0.08252830901421308),
#  0.6326823116867405]

# %%
lin_model = LinearRegression(fit_intercept=True).fit(
    X=dialogue_data_df[all_scores].to_numpy(),
    y=dialogue_data_df["Overall"].to_numpy()
)
dialogue_data_df["lin-reg_all"] = lin_model.predict(dialogue_data_df[all_scores].to_numpy())

pprint(list(zip(all_scores, lin_model.coef_)) + [lin_model.intercept_])
# Out:
# [('cola', 0.02937436650814499),
#  ('sst', 0.028958854808668125),
#  ('mrpc', 0.3248382017389009),
#  ('qnli', -0.1268279865939197),
#  ('qqp', -0.1365986166614643),
#  ('rte', 0.12694834227819343),
#  ('stsb', 0.36497287477086754),
#  ('fact_mrpc', -0.10879131621483915),
#  ('fact_qnli', 0.020632389125348347),
#  ('fact_qqp', 0.06163486408383957),
#  ('fact_rte', 0.06536950338969356),
#  ('fact_stsb', 0.5113217853265033),
#  0.16530204684730748]

# %%
lin_model = LinearRegression(fit_intercept=True).fit(
    X=dialogue_data_df[all_scores].to_numpy(),
    y=dialogue_data_df["Overall"].to_numpy()
)
dialogue_data_df["lin-reg_all"] = lin_model.predict(dialogue_data_df[all_scores].to_numpy())

lr_weights = [("bias", lin_model.intercept_)] + list(zip(all_scores, lin_model.coef_))
lr_weights = pd.DataFrame(lr_weights, columns=["Coefficient", "value"])
lr_weights["\u2800"] = len(lr_weights) * ["\u2800"]
lr_weights["value"] = lr_weights["value"].round(2)

g, ax = plt.subplots(figsize=(10, 3))
sns.heatmap(
    lr_weights.pivot("\u2800", "Coefficient", "value"),
    center=0, vmin=-1, vmax=1,
    annot=True,
    cmap="PiYG",
    square=True,
)

pathlib.Path('../data/plots').mkdir(parents=True, exist_ok=True)
g.suptitle('PersonaChat')
g.savefig("../data/plots/persona_lin-reg_weights.png")
g.savefig("../data/plots/persona_lin-reg_weights.svg")

# %%
lin_reg_cols = [f"lin-reg_{component}" for component in ("pair", "fact", "single", "all")]

# %%
for pred in (all_scores + lin_reg_cols):
    print(f"<<<<<{pred}>>>>>")
    for evaluation in criteria_names:
        x = dialogue_data_df[pred]
        y =  dialogue_data_df[evaluation]
        pears = pearsonr(x, y)
        pears = tuple(round(x,4) for x in pears)
        print(f'{pred}-{evaluation}_pearson: \t{pears}')
        spears = spearmanr(x, y)
        spears = tuple(round(x,4) for x in spears)
        print(f'{pred}-{evaluation}_spearman: \t{spears}')
    print(f"<<<<<{pred}>>>>>")
# Out:
# <<<<<cola>>>>>
# cola-Understandable_pearson: 	(0.0318, 0.5828)
# cola-Understandable_spearman: 	(0.0673, 0.2451)
# cola-Natural_pearson: 	(0.0838, 0.1475)
# cola-Natural_spearman: 	(-0.0309, 0.5945)
# cola-Maintains Context_pearson: 	(-0.0862, 0.1365)
# cola-Maintains Context_spearman: 	(-0.1935, 0.0008)
# cola-Engaging_pearson: 	(-0.0665, 0.251)
# cola-Engaging_spearman: 	(-0.1568, 0.0065)
# cola-Uses Knowledge_pearson: 	(-0.019, 0.7425)
# cola-Uses Knowledge_spearman: 	(-0.1403, 0.015)
# cola-Overall_pearson: 	(-0.0252, 0.6635)
# cola-Overall_spearman: 	(-0.1931, 0.0008)
# <<<<<cola>>>>>
# <<<<<sst>>>>>
# sst-Understandable_pearson: 	(0.0743, 0.1996)
# sst-Understandable_spearman: 	(0.0723, 0.2119)
# sst-Natural_pearson: 	(-0.0064, 0.9119)
# sst-Natural_spearman: 	(0.0294, 0.6123)
# sst-Maintains Context_pearson: 	(0.076, 0.189)
# sst-Maintains Context_spearman: 	(0.0988, 0.0875)
# sst-Engaging_pearson: 	(0.153, 0.008)
# sst-Engaging_spearman: 	(0.1242, 0.0315)
# sst-Uses Knowledge_pearson: 	(0.0422, 0.4663)
# sst-Uses Knowledge_spearman: 	(-0.0034, 0.9531)
# sst-Overall_pearson: 	(0.1172, 0.0424)
# sst-Overall_spearman: 	(0.1068, 0.0647)
# <<<<<sst>>>>>
# <<<<<mrpc>>>>>
# mrpc-Understandable_pearson: 	(0.0857, 0.1385)
# mrpc-Understandable_spearman: 	(0.1098, 0.0574)
# mrpc-Natural_pearson: 	(0.1794, 0.0018)
# mrpc-Natural_spearman: 	(0.241, 0.0)
# mrpc-Maintains Context_pearson: 	(0.3129, 0.0)
# mrpc-Maintains Context_spearman: 	(0.3684, 0.0)
# mrpc-Engaging_pearson: 	(-0.1266, 0.0284)
# mrpc-Engaging_spearman: 	(0.0695, 0.2301)
# mrpc-Uses Knowledge_pearson: 	(-0.0656, 0.2574)
# mrpc-Uses Knowledge_spearman: 	(-0.0112, 0.8468)
# mrpc-Overall_pearson: 	(0.1959, 0.0006)
# mrpc-Overall_spearman: 	(0.2576, 0.0)
# <<<<<mrpc>>>>>
# <<<<<qnli>>>>>
# qnli-Understandable_pearson: 	(-0.1356, 0.0188)
# qnli-Understandable_spearman: 	(-0.1434, 0.0129)
# qnli-Natural_pearson: 	(-0.1821, 0.0015)
# qnli-Natural_spearman: 	(-0.2058, 0.0003)
# qnli-Maintains Context_pearson: 	(-0.3795, 0.0)
# qnli-Maintains Context_spearman: 	(-0.3982, 0.0)
# qnli-Engaging_pearson: 	(0.0163, 0.778)
# qnli-Engaging_spearman: 	(0.0318, 0.5832)
# qnli-Uses Knowledge_pearson: 	(-0.043, 0.458)
# qnli-Uses Knowledge_spearman: 	(-0.049, 0.3981)
# qnli-Overall_pearson: 	(-0.2553, 0.0)
# qnli-Overall_spearman: 	(-0.2434, 0.0)
# <<<<<qnli>>>>>
# <<<<<qqp>>>>>
# qqp-Understandable_pearson: 	(0.0529, 0.3613)
# qqp-Understandable_spearman: 	(0.083, 0.1514)
# qqp-Natural_pearson: 	(0.1071, 0.0639)
# qqp-Natural_spearman: 	(0.1857, 0.0012)
# qqp-Maintains Context_pearson: 	(0.1646, 0.0043)
# qqp-Maintains Context_spearman: 	(0.3472, 0.0)
# qqp-Engaging_pearson: 	(-0.3205, 0.0)
# qqp-Engaging_spearman: 	(-0.0071, 0.9029)
# qqp-Uses Knowledge_pearson: 	(-0.1725, 0.0027)
# qqp-Uses Knowledge_spearman: 	(0.0208, 0.7198)
# qqp-Overall_pearson: 	(0.0276, 0.6345)
# qqp-Overall_spearman: 	(0.2125, 0.0002)
# <<<<<qqp>>>>>
# <<<<<rte>>>>>
# rte-Understandable_pearson: 	(-0.0519, 0.3704)
# rte-Understandable_spearman: 	(-0.0976, 0.0916)
# rte-Natural_pearson: 	(-0.071, 0.22)
# rte-Natural_spearman: 	(-0.1184, 0.0404)
# rte-Maintains Context_pearson: 	(-0.2789, 0.0)
# rte-Maintains Context_spearman: 	(-0.2999, 0.0)
# rte-Engaging_pearson: 	(0.1131, 0.0503)
# rte-Engaging_spearman: 	(0.1269, 0.028)
# rte-Uses Knowledge_pearson: 	(0.0752, 0.1939)
# rte-Uses Knowledge_spearman: 	(0.0827, 0.1531)
# rte-Overall_pearson: 	(-0.0842, 0.1459)
# rte-Overall_spearman: 	(-0.0766, 0.186)
# <<<<<rte>>>>>
# <<<<<stsb>>>>>
# stsb-Understandable_pearson: 	(0.1286, 0.0259)
# stsb-Understandable_spearman: 	(0.1159, 0.0448)
# stsb-Natural_pearson: 	(0.114, 0.0486)
# stsb-Natural_spearman: 	(0.1317, 0.0225)
# stsb-Maintains Context_pearson: 	(0.362, 0.0)
# stsb-Maintains Context_spearman: 	(0.3463, 0.0)
# stsb-Engaging_pearson: 	(0.0889, 0.1242)
# stsb-Engaging_spearman: 	(0.0805, 0.1645)
# stsb-Uses Knowledge_pearson: 	(0.0988, 0.0877)
# stsb-Uses Knowledge_spearman: 	(0.0828, 0.1525)
# stsb-Overall_pearson: 	(0.2591, 0.0)
# stsb-Overall_spearman: 	(0.2396, 0.0)
# <<<<<stsb>>>>>
# <<<<<fact_mrpc>>>>>
# fact_mrpc-Understandable_pearson: 	(0.1219, 0.0349)
# fact_mrpc-Understandable_spearman: 	(0.1938, 0.0007)
# fact_mrpc-Natural_pearson: 	(0.0417, 0.4721)
# fact_mrpc-Natural_spearman: 	(0.055, 0.3425)
# fact_mrpc-Maintains Context_pearson: 	(0.0252, 0.6642)
# fact_mrpc-Maintains Context_spearman: 	(-0.0532, 0.3589)
# fact_mrpc-Engaging_pearson: 	(0.1302, 0.0241)
# fact_mrpc-Engaging_spearman: 	(0.0461, 0.4265)
# fact_mrpc-Uses Knowledge_pearson: 	(-0.0046, 0.9367)
# fact_mrpc-Uses Knowledge_spearman: 	(-0.0571, 0.3247)
# fact_mrpc-Overall_pearson: 	(0.0149, 0.7972)
# fact_mrpc-Overall_spearman: 	(-0.0726, 0.2101)
# <<<<<fact_mrpc>>>>>
# <<<<<fact_qnli>>>>>
# fact_qnli-Understandable_pearson: 	(-0.1256, 0.0296)
# fact_qnli-Understandable_spearman: 	(-0.1494, 0.0095)
# fact_qnli-Natural_pearson: 	(-0.0642, 0.2674)
# fact_qnli-Natural_spearman: 	(-0.0584, 0.3131)
# fact_qnli-Maintains Context_pearson: 	(-0.1478, 0.0103)
# fact_qnli-Maintains Context_spearman: 	(-0.1014, 0.0794)
# fact_qnli-Engaging_pearson: 	(-0.1157, 0.0453)
# fact_qnli-Engaging_spearman: 	(-0.0817, 0.1583)
# fact_qnli-Uses Knowledge_pearson: 	(-0.2733, 0.0)
# fact_qnli-Uses Knowledge_spearman: 	(-0.2613, 0.0)
# fact_qnli-Overall_pearson: 	(-0.1899, 0.0009)
# fact_qnli-Overall_spearman: 	(-0.1734, 0.0026)
# <<<<<fact_qnli>>>>>
# <<<<<fact_qqp>>>>>
# fact_qqp-Understandable_pearson: 	(0.0476, 0.4113)
# fact_qqp-Understandable_spearman: 	(-0.0767, 0.185)
# fact_qqp-Natural_pearson: 	(0.0762, 0.1881)
# fact_qqp-Natural_spearman: 	(-0.0591, 0.3072)
# fact_qqp-Maintains Context_pearson: 	(0.0397, 0.4936)
# fact_qqp-Maintains Context_spearman: 	(0.0774, 0.1813)
# fact_qqp-Engaging_pearson: 	(0.14, 0.0152)
# fact_qqp-Engaging_spearman: 	(0.1365, 0.018)
# fact_qqp-Uses Knowledge_pearson: 	(0.2099, 0.0003)
# fact_qqp-Uses Knowledge_spearman: 	(0.4352, 0.0)
# fact_qqp-Overall_pearson: 	(0.1613, 0.0051)
# fact_qqp-Overall_spearman: 	(0.223, 0.0001)
# <<<<<fact_qqp>>>>>
# <<<<<fact_rte>>>>>
# fact_rte-Understandable_pearson: 	(-0.0296, 0.6098)
# fact_rte-Understandable_spearman: 	(-0.0914, 0.1142)
# fact_rte-Natural_pearson: 	(0.0289, 0.6181)
# fact_rte-Natural_spearman: 	(0.0305, 0.5993)
# fact_rte-Maintains Context_pearson: 	(-0.0371, 0.5225)
# fact_rte-Maintains Context_spearman: 	(-0.0041, 0.944)
# fact_rte-Engaging_pearson: 	(-0.1091, 0.0591)
# fact_rte-Engaging_spearman: 	(-0.0726, 0.21)
# fact_rte-Uses Knowledge_pearson: 	(-0.4052, 0.0)
# fact_rte-Uses Knowledge_spearman: 	(-0.3481, 0.0)
# fact_rte-Overall_pearson: 	(-0.1232, 0.033)
# fact_rte-Overall_spearman: 	(-0.1122, 0.0522)
# <<<<<fact_rte>>>>>
# <<<<<fact_stsb>>>>>
# fact_stsb-Understandable_pearson: 	(0.025, 0.666)
# fact_stsb-Understandable_spearman: 	(0.0307, 0.5961)
# fact_stsb-Natural_pearson: 	(0.0302, 0.6025)
# fact_stsb-Natural_spearman: 	(-0.0032, 0.9555)
# fact_stsb-Maintains Context_pearson: 	(0.1537, 0.0077)
# fact_stsb-Maintains Context_spearman: 	(0.0876, 0.13)
# fact_stsb-Engaging_pearson: 	(0.3419, 0.0)
# fact_stsb-Engaging_spearman: 	(0.3378, 0.0)
# fact_stsb-Uses Knowledge_pearson: 	(0.7329, 0.0)
# fact_stsb-Uses Knowledge_spearman: 	(0.7173, 0.0)
# fact_stsb-Overall_pearson: 	(0.3742, 0.0)
# fact_stsb-Overall_spearman: 	(0.3898, 0.0)
# <<<<<fact_stsb>>>>>
# <<<<<lin-reg_pair>>>>>
# lin-reg_pair-Understandable_pearson: 	(0.1626, 0.0047)
# lin-reg_pair-Understandable_spearman: 	(0.1345, 0.0198)
# lin-reg_pair-Natural_pearson: 	(0.2033, 0.0004)
# lin-reg_pair-Natural_spearman: 	(0.216, 0.0002)
# lin-reg_pair-Maintains Context_pearson: 	(0.4178, 0.0)
# lin-reg_pair-Maintains Context_spearman: 	(0.3981, 0.0)
# lin-reg_pair-Engaging_pearson: 	(0.2185, 0.0001)
# lin-reg_pair-Engaging_spearman: 	(0.2216, 0.0001)
# lin-reg_pair-Uses Knowledge_pearson: 	(0.1909, 0.0009)
# lin-reg_pair-Uses Knowledge_spearman: 	(0.1916, 0.0009)
# lin-reg_pair-Overall_pearson: 	(0.3975, 0.0)
# lin-reg_pair-Overall_spearman: 	(0.3802, 0.0)
# <<<<<lin-reg_pair>>>>>
# <<<<<lin-reg_fact>>>>>
# lin-reg_fact-Understandable_pearson: 	(0.0255, 0.6606)
# lin-reg_fact-Understandable_spearman: 	(0.0328, 0.572)
# lin-reg_fact-Natural_pearson: 	(0.0546, 0.3456)
# lin-reg_fact-Natural_spearman: 	(0.0319, 0.5823)
# lin-reg_fact-Maintains Context_pearson: 	(0.1783, 0.0019)
# lin-reg_fact-Maintains Context_spearman: 	(0.111, 0.0548)
# lin-reg_fact-Engaging_pearson: 	(0.3446, 0.0)
# lin-reg_fact-Engaging_spearman: 	(0.3412, 0.0)
# lin-reg_fact-Uses Knowledge_pearson: 	(0.6959, 0.0)
# lin-reg_fact-Uses Knowledge_spearman: 	(0.702, 0.0)
# lin-reg_fact-Overall_pearson: 	(0.399, 0.0)
# lin-reg_fact-Overall_spearman: 	(0.4135, 0.0)
# <<<<<lin-reg_fact>>>>>
# <<<<<lin-reg_single>>>>>
# lin-reg_single-Understandable_pearson: 	(0.0643, 0.2668)
# lin-reg_single-Understandable_spearman: 	(0.0603, 0.2978)
# lin-reg_single-Natural_pearson: 	(-0.0285, 0.6226)
# lin-reg_single-Natural_spearman: 	(0.0302, 0.6024)
# lin-reg_single-Maintains Context_pearson: 	(0.0974, 0.0922)
# lin-reg_single-Maintains Context_spearman: 	(0.1012, 0.0801)
# lin-reg_single-Engaging_pearson: 	(0.1675, 0.0036)
# lin-reg_single-Engaging_spearman: 	(0.1597, 0.0056)
# lin-reg_single-Uses Knowledge_pearson: 	(0.0464, 0.423)
# lin-reg_single-Uses Knowledge_spearman: 	(0.0644, 0.2661)
# lin-reg_single-Overall_pearson: 	(0.1216, 0.0353)
# lin-reg_single-Overall_spearman: 	(0.1263, 0.0287)
# <<<<<lin-reg_single>>>>>
# <<<<<lin-reg_all>>>>>
# lin-reg_all-Understandable_pearson: 	(0.1214, 0.0355)
# lin-reg_all-Understandable_spearman: 	(0.1218, 0.035)
# lin-reg_all-Natural_pearson: 	(0.1728, 0.0027)
# lin-reg_all-Natural_spearman: 	(0.2044, 0.0004)
# lin-reg_all-Maintains Context_pearson: 	(0.4029, 0.0)
# lin-reg_all-Maintains Context_spearman: 	(0.3707, 0.0)
# lin-reg_all-Engaging_pearson: 	(0.3272, 0.0)
# lin-reg_all-Engaging_spearman: 	(0.3306, 0.0)
# lin-reg_all-Uses Knowledge_pearson: 	(0.5921, 0.0)
# lin-reg_all-Uses Knowledge_spearman: 	(0.5898, 0.0)
# lin-reg_all-Overall_pearson: 	(0.529, 0.0)
# lin-reg_all-Overall_spearman: 	(0.5382, 0.0)
# <<<<<lin-reg_all>>>>>

# %%
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

df = pd.melt(dialogue_data_df)

# Initialize the FacetGrid object
a = sns.cubehelix_palette(len(criteria_names), rot=-0.25, light=0.7)
b = sns.cubehelix_palette(len(single_predictions + pair_predictions + fact_predictions), light=0.5)
c = sns.cubehelix_palette(len(lin_reg_cols), rot=-0.75, light=0.5)
g = sns.FacetGrid(df, row="variable", hue="variable", aspect=15, height=.5, palette=a+b+c)

# Draw the densities in a few steps
g.map(sns.kdeplot, "value",
      bw_adjust=.5, clip_on=False,
      fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, "value", clip_on=False, color="w", lw=2, bw_adjust=.5)
g.map(plt.axhline, y=0, lw=2, clip_on=False)


# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)

g.map(label, "value")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.25)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
g.despine(bottom=True, left=True)
# Out:
# /home/rosko/miniconda3/envs/proxy_indicators/lib/python3.6/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)
# /home/rosko/miniconda3/envs/proxy_indicators/lib/python3.6/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)

# %%
score_df = list()

for pred in (all_scores + lin_reg_cols):
    for evaluation in criteria_names:
        x = dialogue_data_df[pred]
        y =  dialogue_data_df[evaluation]
        pears = pearsonr(x, y)
        pears = tuple(round(x,4) for x in pears)
        spears = spearmanr(x, y)
        spears = tuple(round(x,4) for x in spears)
        
        score_df.append({
            "eval": f"{pred}-{evaluation}",
            "pears":pears[0],
            "pears_p":pears[1],
            "spear":spears[0],
            "spear_p":spears[1],
        })
        
score_df = pd.DataFrame(score_df)

# %%
score_df.to_csv("../data/persona_scores.csv", index=False)

# %%
plot_df = dialogue_data_df.melt(value_vars=criteria_names, id_vars=all_scores + lin_reg_cols)
plot_df = plot_df.rename(columns={"variable": "criteria", "value": "criteria_value"})
plot_df = plot_df.melt(value_vars=all_scores + lin_reg_cols, id_vars =["criteria_value", "criteria"])
plot_df = plot_df.rename(columns={"variable": "prediction", "value": "prediction_value"})
plot_df.head()
# Out:
#    criteria_value        criteria prediction  prediction_value
# 0        1.000000  Understandable       cola          0.619507
# 1        1.000000  Understandable       cola          0.329002
# 2        1.000000  Understandable       cola          0.933082
# 3        0.333333  Understandable       cola          0.995669
# 4        1.000000  Understandable       cola          0.974474

# %%
g = sns.lmplot(
    x="criteria_value", y="prediction_value",
    col="criteria", row="prediction",
    sharex=True, sharey=True,
    data=plot_df[plot_df["prediction"].isin(all_scores)],
    height=2, aspect=1.3,
    x_estimator=np.mean,
)
g.set_titles(col_template="{col_name}", row_template="{row_name}")
g.fig.subplots_adjust(top=0.95)
g.fig.suptitle('PersonaChat')
g.savefig("../data/plots/persona_glue_reg_plot.png")
g.savefig("../data/plots/persona_glue_reg_plot.svg")

# %%
g = sns.lmplot(
    x="criteria_value", y="prediction_value",
    col="criteria", row="prediction",
    sharex=True, sharey=True,
    data=plot_df[plot_df["prediction"].isin(lin_reg_cols)],
    height=2, aspect=1.3,
    x_estimator=np.mean,
)
g.set_titles(col_template="{col_name}", row_template="{row_name}")
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('PersonaChat')
g.savefig("../data/plots/persona_lin-reg_reg_plot.png")
g.savefig("../data/plots/persona_lin-reg_reg_plot.svg")
